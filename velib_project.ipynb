# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize

# %%
#importation du json 
with open('C:/Users/PC/Desktop/desktop/git/projets/python/Data-Analysis-Velib/station_status.json', 'r') as f:
    station_status = json.loads(f.read())
df_station_status = pd.json_normalize(station_status['data'], record_path=["stations"])

# %%
df_station_status
# Out:
#      stationCode  station_id  num_bikes_available  numBikesAvailable  \
# 0          16107   213688169                    1                  1
# 1          11104   516709288                    5                  5
# 2           9020       36255                    8                  8
# 3          12109    37815204                   11                 11
# 4           5001   100769544                   39                 39
# ...          ...         ...                  ...                ...
# 1434       32012   653046369                    1                  1
# 1435       12105   101013666                   22                 22
# 1436        9104   129026597                   17                 17
# 1437       42004   368766689                   20                 20
# 1438        4005   516395829                   13                 13
#
#                num_bikes_available_types  num_docks_available  \
# 0      [{'mechanical': 0}, {'ebike': 1}]                   33
# 1      [{'mechanical': 2}, {'ebike': 3}]                   15
# 2      [{'mechanical': 1}, {'ebike': 7}]                   13
# 3      [{'mechanical': 8}, {'ebike': 3}]                   19
# 4     [{'mechanical': 31}, {'ebike': 8}]                    6
# ...                                  ...                  ...
# 1434   [{'mechanical': 0}, {'ebike': 1}]                   34
# 1435  [{'mechanical': 18}, {'ebike': 4}]                   19
# 1436  [{'mechanical': 14}, {'ebike': 3}]                    5
# 1437  [{'mechanical': 19}, {'ebike': 1}]                    9
# 1438   [{'mechanical': 6}, {'ebike': 7}]                    3
#
#       numDocksAvailable  is_installed  is_returning  is_renting  last_reported
# 0                    33             1             1           1     1645639734
# 1                    15             1             1           1     1645639555
# 2                    13             1             1           1     1645639785
# 3                    19             1             1           1     1645639898
# 4                     6             1             1           1     1645639858
# ...                 ...           ...           ...         ...            ...
# 1434                 34             1             1           1     1645639809
# 1435                 19             1             1           1     1645639874
# 1436                  5             1             1           1     1645639801
# 1437                  9             1             1           1     1645639879
# 1438                  3             1             1           1     1645639888
#
# [1439 rows x 11 columns]

# %%
'''importation du json station information donnant les attributs suivants:
array data contenant les informations suviantes:
-capacity : renseigne le nombre de bornes dans une station
- lat : définit la lattitude
- long : définit la longitude
- name: le nom de la station
- station_id: élement int unique désignant une station 

'''

with open('C:/Users/PC/Desktop/desktop/git/projets/python/Data-Analysis-Velib/station_information.json', 'r') as f:
    station_information = json.loads(f.read())
df_station_information= pd.json_normalize(station_information['data'], record_path=["stations"])

# %%
df_station_information
# Out:
#       station_id                                 name        lat       lon  \
# 0      213688169        Benjamin Godard - Victor Hugo  48.865983  2.275725
# 1      516709288  Charonne - Robert et Sonia Delauney  48.855908  2.392571
# 2          36255                   Toudouze - Clauzel  48.879296  2.337360
# 3       37815204                     Mairie du 12Ã¨me  48.840855  2.387555
# 4      100769544                Harpe - Saint-Germain  48.851519  2.343670
# ...          ...                                  ...        ...       ...
# 1434   315022587  Malesherbes - Place de la Madeleine  48.870406  2.323244
# 1435   101013666                       Bercy - Villot  48.841795  2.376785
# 1436   653046369                     Carrefour Pleyel  48.920342  2.343854
# 1437   478732841               Sebastopol - Rambuteau  48.861818  2.350138
# 1438   129026597                 Caumartin - Provence  48.874423  2.328469
#
#       capacity stationCode rental_methods
# 0           35       16107            NaN
# 1           20       11104            NaN
# 2           21        9020   [CREDITCARD]
# 3           30       12109            NaN
# 4           45        5001   [CREDITCARD]
# ...        ...         ...            ...
# 1434        67        8004   [CREDITCARD]
# 1435        34       12105   [CREDITCARD]
# 1436        36       32012   [CREDITCARD]
# 1437        16        4104            NaN
# 1438        22        9104   [CREDITCARD]
#
# [1439 rows x 7 columns]

# %%
df
# Out:
#      stationCode  station_id  num_bikes_available  numBikesAvailable  \
# 0          16107   213688169                    1                  1
# 1          11104   516709288                    5                  5
# 2           9020       36255                    8                  8
# 3          12109    37815204                   11                 11
# 4           5001   100769544                   39                 39
# ...          ...         ...                  ...                ...
# 1434       32012   653046369                    1                  1
# 1435       12105   101013666                   22                 22
# 1436        9104   129026597                   17                 17
# 1437       42004   368766689                   20                 20
# 1438        4005   516395829                   13                 13
#
#                num_bikes_available_types  num_docks_available  \
# 0      [{'mechanical': 0}, {'ebike': 1}]                   33
# 1      [{'mechanical': 2}, {'ebike': 3}]                   15
# 2      [{'mechanical': 1}, {'ebike': 7}]                   13
# 3      [{'mechanical': 8}, {'ebike': 3}]                   19
# 4     [{'mechanical': 31}, {'ebike': 8}]                    6
# ...                                  ...                  ...
# 1434   [{'mechanical': 0}, {'ebike': 1}]                   34
# 1435  [{'mechanical': 18}, {'ebike': 4}]                   19
# 1436  [{'mechanical': 14}, {'ebike': 3}]                    5
# 1437  [{'mechanical': 19}, {'ebike': 1}]                    9
# 1438   [{'mechanical': 6}, {'ebike': 7}]                    3
#
#       numDocksAvailable  is_installed  is_returning  is_renting  last_reported
# 0                    33             1             1           1     1645639734
# 1                    15             1             1           1     1645639555
# 2                    13             1             1           1     1645639785
# 3                    19             1             1           1     1645639898
# 4                     6             1             1           1     1645639858
# ...                 ...           ...           ...         ...            ...
# 1434                 34             1             1           1     1645639809
# 1435                 19             1             1           1     1645639874
# 1436                  5             1             1           1     1645639801
# 1437                  9             1             1           1     1645639879
# 1438                  3             1             1           1     1645639888
#
# [1439 rows x 11 columns]

# %%
# Out:
#                                                 0     \
# 0  {'stationCode': '16107', 'station_id': 2136881...
#
#                                                 1     \
# 0  {'stationCode': '11104', 'station_id': 5167092...
#
#                                                 2     \
# 0  {'stationCode': '9020', 'station_id': 36255, '...
#
#                                                 3     \
# 0  {'stationCode': '12109', 'station_id': 3781520...
#
#                                                 4     \
# 0  {'stationCode': '5001', 'station_id': 10076954...
#
#                                                 5     \
# 0  {'stationCode': '10013', 'station_id': 1230951...
#
#                                                 6     \
# 0  {'stationCode': '8026', 'station_id': 12082788...
#
#                                                 7     \
# 0  {'stationCode': '14111', 'station_id': 2510399...
#
#                                                 8     \
# 0  {'stationCode': '6003', 'station_id': 37874517...
#
#                                                 9     ...  \
# 0  {'stationCode': '13007', 'station_id': 6649139...  ...
#
#                                                 1429  \
# 0  {'stationCode': '8002', 'station_id': 39440465...
#
#                                                 1430  \
# 0  {'stationCode': '15056', 'station_id': 3474297...
#
#                                                 1431  \
# 0  {'stationCode': '8004', 'station_id': 31502258...
#
#                                                 1432  \
# 0  {'stationCode': '13123', 'station_id': 1062807...
#
#                                                 1433  \
# 0  {'stationCode': '4104', 'station_id': 47873284...
#
#                                                 1434  \
# 0  {'stationCode': '32012', 'station_id': 6530463...
#
#                                                 1435  \
# 0  {'stationCode': '12105', 'station_id': 1010136...
#
#                                                 1436  \
# 0  {'stationCode': '9104', 'station_id': 12902659...
#
#                                                 1437  \
# 0  {'stationCode': '42004', 'station_id': 3687666...
#
#                                                 1438
# 0  {'stationCode': '4005', 'station_id': 51639582...
#
# [1 rows x 1439 columns]

# %%
velos
# Out:
#           lastUpdatedOther   ttl  \
# stations        1645640933  3600
#
#                                                        data
# stations  [{'stationCode': '16107', 'station_id': 213688...
