# %% [markdown]
# Données NYC

# %% [markdown]
# Initialisation

# %%
import plotly.express as px
from sqlalchemy import create_engine, text
import pandas as pd
import numpy as np

# %% [markdown]
# Chargement des données NYC

# %%
stations = pd.read_csv('/Users/rymarajhi/Desktop/Python/nyc_stations_data.csv')
stations
# Out:
#          station_id  num_bikes_available  num_docks_available  is_installed  \
# 0               339                    2                   39             1
# 1               340                   23                    3             1
# 2               341                    8                   11             1
# 3               342                   19                   10             1
# 4               343                    6                   17             1
# ...             ...                  ...                  ...           ...
# 4800310         331                    0                    0             1
# 4800311         332                   13                   19             1
# 4800312         334                   36                    7             1
# 4800313         335                   24                    0             1
# 4800314         336                   41                   12             1
#
# ...

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800315 entries, 0 to 4800314
# Data columns (total 22 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   station_id                      int64
#  1   num_bikes_available             int64
#  2   num_docks_available             int64
#  3   is_installed                    int64
#  4   is_returning                    int64
#  5   is_renting                      int64
#  6   last_reported                   object
#  7   num_ebikes_available            int64
#  8   time_queried                    object
#  9   name                            object
#  10  lat                             float64
#  11  lon                             float64
#  12  capacity                        int64
#  13  rental_methods                  object
#  14  legacy_id                       int64
#  15  station_status                  object
#  16  num_docks_disabled              int64
# ...

# %% [markdown]
# Choisir les bonnes donnéess

# %%
#On supprime les colonnes dont nous n'avons pas besoin 
stations = pd.DataFrame(stations)
stations = stations.drop(['num_ebikes_available','rental_methods','region_id', 'station_type', 'has_kiosk','electric_bike_surcharge_waiver','num_bikes_disabled','num_docks_disabled','station_status','legacy_id'], axis=1)

# %%
#On ajoute une colonne "ville" = NYC ou PARIS pour pouvoir comparer les deux tables
stations['ville'] = 'NYC'
stations #Création Data Frame
# Out:
#          station_id  num_bikes_available  num_docks_available  is_installed  \
# 0               339                    2                   39             1
# 1               340                   23                    3             1
# 2               341                    8                   11             1
# 3               342                   19                   10             1
# 4               343                    6                   17             1
# ...             ...                  ...                  ...           ...
# 4800310         331                    0                    0             1
# 4800311         332                   13                   19             1
# 4800312         334                   36                    7             1
# 4800313         335                   24                    0             1
# 4800314         336                   41                   12             1
#
# ...
